# %% [markdown]
# # Implementation of Linear Regression using Gradient Descent.

# %%
# Imports

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create X in 1-d array and y in 1-d array

# %%
X = np.array([[2.9, 0.9, 1, 3.8, 1.6, 2.6, 5, 1, 3, 3.3, 4.3, 0.2, 3.9, 1.5, 4.4, 2.9, 4.1, 1.5, 2.4, 5.0]])
y = np.array([[6.5, 0.7, 0.8, 7.6, 2.3, 5.6, 10, 0.3, 7.4, 4.8, 7.3, 0, 6.2, 3.7, 7.4, 4, 9, 4.2, 5.8, 10]])

# %% [markdown]
# Visualize the dots throught matplotlib

# %%
plt.scatter(X, y)

plt.show()

# %% [markdown]
# Build the linear regression model

# %%
class LinearRegression:
    def __init__(self, print_cost=False):
        self.learning_rate = 0.01
        self.total_iterations = 10000
        self.print_cost = print_cost

    def y_hat(self, X, w):
        return np.dot(w.T, X)

    def cost(self, yhat, y):
        C = 1 / self.m * np.sum(np.power(yhat - y, 2))

        return C

    def gradient_descent(self, w, X, y, yhat):
        dCdW = 2 / self.m * np.dot(X, (yhat - y).T)
        w = w - self.learning_rate * dCdW

        return w

    def main(self, X, y):
        # Add x1 = 1
        ones = np.ones((1, X.shape[1]))
        X = np.append(ones, X, axis=0)

        self.m = X.shape[1]
        self.n = X.shape[0]

        w = np.zeros((self.n, 1))

        for it in range(self.total_iterations + 1):
            yhat = self.y_hat(X, w)
            cost = self.cost(yhat, y)

            if it % 2000 == 0 and self.print_cost:
                print(f"Cost at iteration {it} is {cost}")

            w = self.gradient_descent(w, X, y, yhat)
        
        yhat = self.y_hat(X, w)

        return w, yhat

# %%
regression = LinearRegression(print_cost=True)
w, y_hat = regression.main(X, y)
# Out:
# Cost at iteration 0 is 36.207
# Cost at iteration 2000 is 1.146063454015902
# Cost at iteration 4000 is 1.1460634225746442
# Cost at iteration 6000 is 1.1460634225746384
# Cost at iteration 8000 is 1.1460634225746384
# Cost at iteration 10000 is 1.1460634225746384

# %%
plt.scatter(X, y)
plt.plot(X[0], y_hat[0], c='red')

plt.show()

# %% [markdown]
# Try with X is 2-d array

# %%
X = np.random.rand(2000).reshape(1000,2)
X.shape
# Out:
# (1000, 2)

# %%
y = np.array(X[:, 0]**2 + X[:, 1]**2).reshape(1,1000)
y.shape
# Out:
# (1, 1000)

# %%
# pop-up plots

# %matplotlib inline

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:,0], X[:,1], y)

plt.show()

# %matplotlib qt

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:,0], X[:,1], y)

plt.show()

# %%
# %matplotlib inline

# %%
regression = LinearRegression(print_cost=True)
w, y_hat = regression.main(X.T, y)
# Out:
# Cost at iteration 0 is 0.6224738674608893
# Cost at iteration 2000 is 0.012297529953851557
# Cost at iteration 4000 is 0.01087935572038307
# Cost at iteration 6000 is 0.010858459365528438
# Cost at iteration 8000 is 0.010858151461069249
# Cost at iteration 10000 is 0.010858146924141611

# %%
# %matplotlib inline

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:,0], X[:,1], y)
ax.scatter(X[:,0], X[:,1], y_hat, c='red')
ax.view_init(30, 30)

plt.show()

# %matplotlib qt

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:,0], X[:,1], y)
ax.scatter(X[:,0], X[:,1], y_hat, c='red')

plt.show()

# %%
# %matplotlib inline
